# %%
import tensorflow.compat.v1 as tf
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Disable TensorFlow 2 behavior
tf.disable_v2_behavior()

# Load MNIST dataset manually
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape(-1, 784).astype(np.float32) / 255.0
test_images = test_images.reshape(-1, 784).astype(np.float32) / 255.0
train_labels = np.eye(10)[train_labels]
test_labels = np.eye(10)[test_labels]

# Network Parameters
input_size = 784
output_size = 10
learning_rate = 0.01
epochs = 20
batch_size = 10

# Hyperparameters to tune
activation_functions = {'relu': tf.nn.relu, 'sigmoid': tf.nn.sigmoid, 'tanh': tf.nn.tanh}
hidden_layer_sizes = [256, 128, 64]

# Placeholder for results
results = []

for activation_name, activation_func in activation_functions.items():
    for hidden_layer_size in hidden_layer_sizes:
        print(f"Training with Activation: {activation_name}, Hidden Layer Size: {hidden_layer_size}")

        X = tf.placeholder(tf.float32, [None, input_size])
        Y = tf.placeholder(tf.float32, [None, output_size])

        weights = {
            'h1': tf.Variable(tf.random_normal([input_size, hidden_layer_size])),
            'out': tf.Variable(tf.random_normal([hidden_layer_size, output_size]))
        }
        biases = {
            'b1': tf.Variable(tf.random_normal([hidden_layer_size])),
            'out': tf.Variable(tf.random_normal([output_size]))
        }

        def neural_network(x):
            layer1 = activation_func(tf.add(tf.matmul(x, weights['h1']), biases['b1']))
            output_layer = tf.add(tf.matmul(layer1, weights['out']), biases['out'])
            return output_layer

        logits = neural_network(X)
        predictions = tf.nn.softmax(logits)

        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=logits, labels=Y))
        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

        correct_pred = tf.equal(tf.argmax(predictions, 1), tf.argmax(Y, 1))
        accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            start_time = time.time()
            train_losses = []
            train_accuracies = []

            for epoch in range(epochs):
                avg_loss = 0
                total_batches = train_images.shape[0] // batch_size

                for i in range(total_batches):
                    batch_x = train_images[i * batch_size:(i + 1) * batch_size]
                    batch_y = train_labels[i * batch_size:(i + 1) * batch_size]
                    _, c, acc = sess.run([optimizer, loss, accuracy], feed_dict={X: batch_x, Y: batch_y})
                    avg_loss += c

                avg_loss /= total_batches
                train_losses.append(avg_loss)
                train_accuracies.append(acc)
                print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}, Accuracy: {acc:.4f}")

            end_time = time.time()
            execution_time = end_time - start_time

            test_acc, preds = sess.run([accuracy, predictions], feed_dict={X: test_images, Y: test_labels})
            results.append((activation_name, hidden_layer_size, test_acc, execution_time))

            print(f"Final Test Accuracy: {test_acc:.4f}")
            print(f"Execution Time: {execution_time:.2f} seconds\n")

            # Plot loss and accuracy curves
            plt.figure(figsize=(12, 5))
            plt.subplot(1, 2, 1)
            plt.plot(range(epochs), train_losses, label='Loss')
            plt.xlabel('Epochs')
            plt.ylabel('Loss')
            plt.title(f'Loss Curve - {activation_name}, {hidden_layer_size}')
            plt.legend()

            plt.subplot(1, 2, 2)
            plt.plot(range(epochs), train_accuracies, label='Accuracy', color='green')
            plt.xlabel('Epochs')
            plt.ylabel('Accuracy')
            plt.title(f'Accuracy Curve - {activation_name}, {hidden_layer_size}')
            plt.legend()
            plt.show()

            y_true = np.argmax(test_labels, axis=1)
            y_pred = np.argmax(preds, axis=1)
            cm = confusion_matrix(y_true, y_pred)
            plt.figure(figsize=(8, 6))
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
            plt.xlabel('Predicted')
            plt.ylabel('Actual')
            plt.title(f'Confusion Matrix - {activation_name}, {hidden_layer_size}')
            plt.show()

print("\nHyperparameter Tuning Results:")
for activation, hl_size, acc, time_taken in results:
    print(f"Activation: {activation}, Hidden Layer: {hl_size}, Test Accuracy: {acc:.4f}, Time: {time_taken:.2f}s")
# Out:
# Training with Activation: relu, Hidden Layer Size: 256
# Epoch 1, Loss: 2.5476, Accuracy: 1.0000
# Epoch 2, Loss: 0.3562, Accuracy: 1.0000
# Epoch 3, Loss: 0.2929, Accuracy: 1.0000
# Epoch 4, Loss: 0.2525, Accuracy: 1.0000
# Epoch 5, Loss: 0.2306, Accuracy: 1.0000
# Epoch 6, Loss: 0.2183, Accuracy: 1.0000
# Epoch 7, Loss: 0.2177, Accuracy: 0.9000
# Epoch 8, Loss: 0.2109, Accuracy: 1.0000
# Epoch 9, Loss: 0.2028, Accuracy: 1.0000
# Epoch 10, Loss: 0.2025, Accuracy: 1.0000
# Epoch 11, Loss: 0.1899, Accuracy: 1.0000
# Epoch 12, Loss: 0.1853, Accuracy: 1.0000
# Epoch 13, Loss: 0.1777, Accuracy: 1.0000
# Epoch 14, Loss: 0.1699, Accuracy: 1.0000
# Epoch 15, Loss: 0.1771, Accuracy: 1.0000
# Epoch 16, Loss: 0.1614, Accuracy: 1.0000
# Epoch 17, Loss: 0.1712, Accuracy: 1.0000
# Epoch 18, Loss: 0.1647, Accuracy: 1.0000
# Epoch 19, Loss: 0.1663, Accuracy: 1.0000
# Epoch 20, Loss: 0.1635, Accuracy: 1.0000
# Final Test Accuracy: 0.9466
# Execution Time: 163.35 seconds
# Training with Activation: relu, Hidden Layer Size: 128
# Epoch 1, Loss: 1.6755, Accuracy: 1.0000
# Epoch 2, Loss: 0.3180, Accuracy: 1.0000
# Epoch 3, Loss: 0.2689, Accuracy: 1.0000
# Epoch 4, Loss: 0.2476, Accuracy: 1.0000
# Epoch 5, Loss: 0.2331, Accuracy: 1.0000
# Epoch 6, Loss: 0.2157, Accuracy: 1.0000
# Epoch 7, Loss: 0.2109, Accuracy: 1.0000
# Epoch 8, Loss: 0.2105, Accuracy: 1.0000
# Epoch 9, Loss: 0.1975, Accuracy: 1.0000
# Epoch 10, Loss: 0.1915, Accuracy: 1.0000
# Epoch 11, Loss: 0.1923, Accuracy: 1.0000
# Epoch 12, Loss: 0.1825, Accuracy: 1.0000
# Epoch 13, Loss: 0.1783, Accuracy: 1.0000
# Epoch 14, Loss: 0.1709, Accuracy: 1.0000
# Epoch 15, Loss: 0.1763, Accuracy: 1.0000
# Epoch 16, Loss: 0.1740, Accuracy: 1.0000
# Epoch 17, Loss: 0.1624, Accuracy: 1.0000
# Epoch 18, Loss: 0.1725, Accuracy: 1.0000
# Epoch 19, Loss: 0.1644, Accuracy: 1.0000
# Epoch 20, Loss: 0.1689, Accuracy: 1.0000
# Final Test Accuracy: 0.9423
# Execution Time: 162.70 seconds
# Training with Activation: relu, Hidden Layer Size: 64
# Epoch 1, Loss: 0.9953, Accuracy: 1.0000
# Epoch 2, Loss: 0.2971, Accuracy: 1.0000
# Epoch 3, Loss: 0.2549, Accuracy: 1.0000
# Epoch 4, Loss: 0.2376, Accuracy: 1.0000
# Epoch 5, Loss: 0.2187, Accuracy: 1.0000
# Epoch 6, Loss: 0.2080, Accuracy: 1.0000
# Epoch 7, Loss: 0.2056, Accuracy: 0.9000
# Epoch 8, Loss: 0.1998, Accuracy: 1.0000
# Epoch 9, Loss: 0.1939, Accuracy: 1.0000
# Epoch 10, Loss: 0.1934, Accuracy: 1.0000
# Epoch 11, Loss: 0.1854, Accuracy: 1.0000
# Epoch 12, Loss: 0.1868, Accuracy: 0.9000
# Epoch 13, Loss: 0.1851, Accuracy: 1.0000
# Epoch 14, Loss: 0.1743, Accuracy: 1.0000
# Epoch 15, Loss: 0.1730, Accuracy: 1.0000
# Epoch 16, Loss: 0.1706, Accuracy: 1.0000
# Epoch 17, Loss: 0.1721, Accuracy: 1.0000
# Epoch 18, Loss: 0.1719, Accuracy: 1.0000
# Epoch 19, Loss: 0.1710, Accuracy: 1.0000
# Epoch 20, Loss: 0.1632, Accuracy: 1.0000
# Final Test Accuracy: 0.9420
# Execution Time: 160.96 seconds
# Training with Activation: sigmoid, Hidden Layer Size: 256
# Epoch 1, Loss: 0.5079, Accuracy: 1.0000
# Epoch 2, Loss: 0.2764, Accuracy: 1.0000
# Epoch 3, Loss: 0.2551, Accuracy: 1.0000
# Epoch 4, Loss: 0.2290, Accuracy: 1.0000
# Epoch 5, Loss: 0.2058, Accuracy: 1.0000
# Epoch 6, Loss: 0.1954, Accuracy: 1.0000
# Epoch 7, Loss: 0.1872, Accuracy: 1.0000
# Epoch 8, Loss: 0.1813, Accuracy: 1.0000
# Epoch 9, Loss: 0.1715, Accuracy: 1.0000
# Epoch 10, Loss: 0.1652, Accuracy: 1.0000
# Epoch 11, Loss: 0.1624, Accuracy: 1.0000
# Epoch 12, Loss: 0.1576, Accuracy: 1.0000
# Epoch 13, Loss: 0.1589, Accuracy: 1.0000
# Epoch 14, Loss: 0.1431, Accuracy: 1.0000
# Epoch 15, Loss: 0.1446, Accuracy: 1.0000
# Epoch 16, Loss: 0.1315, Accuracy: 1.0000
# Epoch 17, Loss: 0.1348, Accuracy: 1.0000
# Epoch 18, Loss: 0.1371, Accuracy: 1.0000
# Epoch 19, Loss: 0.1276, Accuracy: 1.0000
# Epoch 20, Loss: 0.1260, Accuracy: 1.0000
# Final Test Accuracy: 0.9622
# Execution Time: 162.51 seconds
# Training with Activation: sigmoid, Hidden Layer Size: 128
# Epoch 1, Loss: 0.4039, Accuracy: 1.0000
# Epoch 2, Loss: 0.2315, Accuracy: 1.0000
# Epoch 3, Loss: 0.1958, Accuracy: 1.0000
# Epoch 4, Loss: 0.1798, Accuracy: 1.0000
# Epoch 5, Loss: 0.1604, Accuracy: 1.0000
# Epoch 6, Loss: 0.1567, Accuracy: 1.0000
# Epoch 7, Loss: 0.1546, Accuracy: 1.0000
# Epoch 8, Loss: 0.1444, Accuracy: 1.0000
# Epoch 9, Loss: 0.1382, Accuracy: 1.0000
# Epoch 10, Loss: 0.1261, Accuracy: 1.0000
# Epoch 11, Loss: 0.1245, Accuracy: 1.0000
# Epoch 12, Loss: 0.1189, Accuracy: 1.0000
# Epoch 13, Loss: 0.1153, Accuracy: 1.0000
# Epoch 14, Loss: 0.1087, Accuracy: 1.0000
# Epoch 15, Loss: 0.1059, Accuracy: 1.0000
# Epoch 16, Loss: 0.1043, Accuracy: 1.0000
# Epoch 17, Loss: 0.1011, Accuracy: 1.0000
# Epoch 18, Loss: 0.0982, Accuracy: 1.0000
# Epoch 19, Loss: 0.0913, Accuracy: 1.0000
# Epoch 20, Loss: 0.0989, Accuracy: 1.0000
# Final Test Accuracy: 0.9619
# Execution Time: 163.57 seconds
# Training with Activation: sigmoid, Hidden Layer Size: 64
# Epoch 1, Loss: 0.3781, Accuracy: 1.0000
# Epoch 2, Loss: 0.2221, Accuracy: 1.0000
# Epoch 3, Loss: 0.1887, Accuracy: 1.0000
# Epoch 4, Loss: 0.1667, Accuracy: 1.0000
# Epoch 5, Loss: 0.1509, Accuracy: 1.0000
# Epoch 6, Loss: 0.1467, Accuracy: 1.0000
# Epoch 7, Loss: 0.1350, Accuracy: 1.0000
# Epoch 8, Loss: 0.1348, Accuracy: 1.0000
# Epoch 9, Loss: 0.1218, Accuracy: 1.0000
# Epoch 10, Loss: 0.1105, Accuracy: 1.0000
# Epoch 11, Loss: 0.1161, Accuracy: 1.0000
# Epoch 12, Loss: 0.1110, Accuracy: 1.0000
# Epoch 13, Loss: 0.1056, Accuracy: 1.0000
# Epoch 14, Loss: 0.1038, Accuracy: 1.0000
# Epoch 15, Loss: 0.1007, Accuracy: 1.0000
# Epoch 16, Loss: 0.0960, Accuracy: 1.0000
# Epoch 17, Loss: 0.0963, Accuracy: 1.0000
# Epoch 18, Loss: 0.0934, Accuracy: 1.0000
# Epoch 19, Loss: 0.0883, Accuracy: 1.0000
# Epoch 20, Loss: 0.0894, Accuracy: 1.0000
# Final Test Accuracy: 0.9598
# Execution Time: 161.65 seconds
# Training with Activation: tanh, Hidden Layer Size: 256
# Epoch 1, Loss: 1.0541, Accuracy: 1.0000
# Epoch 2, Loss: 0.6224, Accuracy: 1.0000
# Epoch 3, Loss: 0.5425, Accuracy: 1.0000
# Epoch 4, Loss: 0.5140, Accuracy: 1.0000
# Epoch 5, Loss: 0.4761, Accuracy: 1.0000
# Epoch 6, Loss: 0.4798, Accuracy: 1.0000
# Epoch 7, Loss: 0.4671, Accuracy: 1.0000
# Epoch 8, Loss: 0.4362, Accuracy: 1.0000
# Epoch 9, Loss: 0.4370, Accuracy: 1.0000
# Epoch 10, Loss: 0.4261, Accuracy: 1.0000
# Epoch 11, Loss: 0.4103, Accuracy: 1.0000
# Epoch 12, Loss: 0.4262, Accuracy: 1.0000
# Epoch 13, Loss: 0.4132, Accuracy: 1.0000
# Epoch 14, Loss: 0.4085, Accuracy: 1.0000
# Epoch 15, Loss: 0.3991, Accuracy: 1.0000
# Epoch 16, Loss: 0.4053, Accuracy: 1.0000
# Epoch 17, Loss: 0.3888, Accuracy: 1.0000
# Epoch 18, Loss: 0.3724, Accuracy: 1.0000
# Epoch 19, Loss: 0.4033, Accuracy: 1.0000
# Epoch 20, Loss: 0.3856, Accuracy: 1.0000
# Final Test Accuracy: 0.9434
# Execution Time: 161.63 seconds
# Training with Activation: tanh, Hidden Layer Size: 128
# Epoch 1, Loss: 0.7683, Accuracy: 1.0000
# Epoch 2, Loss: 0.4085, Accuracy: 1.0000
# Epoch 3, Loss: 0.3654, Accuracy: 1.0000
# Epoch 4, Loss: 0.3309, Accuracy: 1.0000
# Epoch 5, Loss: 0.3086, Accuracy: 1.0000
# Epoch 6, Loss: 0.2898, Accuracy: 1.0000
# Epoch 7, Loss: 0.2816, Accuracy: 1.0000
# Epoch 8, Loss: 0.2715, Accuracy: 1.0000
# Epoch 9, Loss: 0.2590, Accuracy: 1.0000
# Epoch 10, Loss: 0.2595, Accuracy: 1.0000
# Epoch 11, Loss: 0.2557, Accuracy: 1.0000
# Epoch 12, Loss: 0.2431, Accuracy: 1.0000
# Epoch 13, Loss: 0.2487, Accuracy: 1.0000
# Epoch 14, Loss: 0.2400, Accuracy: 1.0000
# Epoch 15, Loss: 0.2380, Accuracy: 1.0000
# Epoch 16, Loss: 0.2329, Accuracy: 1.0000
# Epoch 17, Loss: 0.2303, Accuracy: 1.0000
# Epoch 18, Loss: 0.2310, Accuracy: 1.0000
# Epoch 19, Loss: 0.2344, Accuracy: 1.0000
# Epoch 20, Loss: 0.2322, Accuracy: 1.0000
# Final Test Accuracy: 0.9494
# Execution Time: 159.52 seconds
# Training with Activation: tanh, Hidden Layer Size: 64
# Epoch 1, Loss: 0.5623, Accuracy: 1.0000
# Epoch 2, Loss: 0.3156, Accuracy: 1.0000
# Epoch 3, Loss: 0.2909, Accuracy: 1.0000
# Epoch 4, Loss: 0.2589, Accuracy: 1.0000
# Epoch 5, Loss: 0.2354, Accuracy: 1.0000
# Epoch 6, Loss: 0.2244, Accuracy: 1.0000
# Epoch 7, Loss: 0.2145, Accuracy: 1.0000
# Epoch 8, Loss: 0.2110, Accuracy: 1.0000
# Epoch 9, Loss: 0.2020, Accuracy: 1.0000
# Epoch 10, Loss: 0.1985, Accuracy: 1.0000
# Epoch 11, Loss: 0.1959, Accuracy: 1.0000
# Epoch 12, Loss: 0.1992, Accuracy: 1.0000
# Epoch 13, Loss: 0.1827, Accuracy: 1.0000
# Epoch 14, Loss: 0.1939, Accuracy: 1.0000
# Epoch 15, Loss: 0.1808, Accuracy: 1.0000
# Epoch 16, Loss: 0.1845, Accuracy: 1.0000
# Epoch 17, Loss: 0.1784, Accuracy: 1.0000
# Epoch 18, Loss: 0.1753, Accuracy: 1.0000
# Epoch 19, Loss: 0.1680, Accuracy: 1.0000
# Epoch 20, Loss: 0.1630, Accuracy: 1.0000
# Final Test Accuracy: 0.9471
# Execution Time: 161.89 seconds
# Hyperparameter Tuning Results:
# Activation: relu, Hidden Layer: 256, Test Accuracy: 0.9466, Time: 163.35s
# Activation: relu, Hidden Layer: 128, Test Accuracy: 0.9423, Time: 162.70s
# Activation: relu, Hidden Layer: 64, Test Accuracy: 0.9420, Time: 160.96s
# Activation: sigmoid, Hidden Layer: 256, Test Accuracy: 0.9622, Time: 162.51s
# Activation: sigmoid, Hidden Layer: 128, Test Accuracy: 0.9619, Time: 163.57s
# Activation: sigmoid, Hidden Layer: 64, Test Accuracy: 0.9598, Time: 161.65s
# Activation: tanh, Hidden Layer: 256, Test Accuracy: 0.9434, Time: 161.63s
# Activation: tanh, Hidden Layer: 128, Test Accuracy: 0.9494, Time: 159.52s
# Activation: tanh, Hidden Layer: 64, Test Accuracy: 0.9471, Time: 161.89s
